# %% [markdown]
# # DX 602 Week 10 Homework

# %% [markdown]
# ## Introduction
#
# In this homework, you will practice exploratory analysis using Pandas, and review previous material in this module.
#
# The first ten problems of this homework will be manually graded due to their visual nature.
# The remaining problems will be graded automatically like usual.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to this GitHub repository of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Shared Imports
#
# Do not install or use any additional modules.
# Installing additional modules may result in an autograder failure resulting in zero points for some or all problems.

# %%
import math
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Shared Data

# %% [markdown]
# The following red wine data set is from the paper ["Modeling wine preferences by data mining from physicochemical properties"](https://repositorium.sdum.uminho.pt/bitstream/1822/10029/1/wine5.pdf).

# %%
red_wine = pd.read_csv("https://github.com/EpistasisLab/pmlb/raw/refs/heads/master/datasets/wine_quality_red/wine_quality_red.tsv.gz", sep="\t")
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  target
# 0      9.4       5
# 1      9.8       5
# 2      9.8       5
# 3      9.8       6
# 4      9.4       5

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1 (manually graded)
#
# Plot histograms of every column of the red wine data set in the `red_wine` variable above.
# Make sure to adjust the spacing for legibility so that the labels do not overlap the charts.

# %%
# YOUR CHANGES HERE

# plot
pd.plotting.hist_frame(red_wine)
# add title
plt.suptitle("Red Wine Histograms", fontsize=16)
# adjust spacing
plt.subplots_adjust(wspace=0.9, hspace=0.9)

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 2 (manually graded)
#
# Plot a scatter plot of the fixed acidity and citric acid columns of the red wine data set in the `red_wine` variable above.
# Make sure that both axes are labeled.

# %%
# YOUR CHANGES HERE

# plot
red_wine.plot.scatter("fixed acidity", "citric acid", alpha=0.5)
# title only as the labels were automatically added
plt.title("Fixed Acidity and Citric Acid of Red Wine")
# Out:
# Text(0.5, 1.0, 'Fixed Acidity and Citric Acid of Red Wine')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 3 (manually graded)
#
# Repeat the scatter plot of the fixed acidity and citric acid columns of the red wine data set.
# This time, make the y axis start from zero.

# %%
# YOUR CHANGES HERE

# plot & set y axis
q3 = red_wine.plot.scatter("fixed acidity", "citric acid", alpha=0.5)
# set y lim
q3.set_ylim(0)
# title only, axes are automatically labeled
plt.title("Fixed Acidity and Citric Acid of Red Wine, ylim=0")
# Out:
# Text(0.5, 1.0, 'Fixed Acidity and Citric Acid of Red Wine, ylim=0')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 4 (manually graded)
#
# Plot a histogram of the `target` column of the red wine data set.
# (This column was supposed to represent the quality of the wine.)

# %%
# YOUR CHANGES HERE

# plot
red_wine['target'].plot(kind='hist', title="Red Wine Target")

# add x label
plt.xlabel("Target")
# Out:
# Text(0.5, 0, 'Target')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 5 (manually graded)
#
# In the video "Using Subplots with Pandas", the following chart plotted the average of each input column as a function of the abalone target column "Rings".
# Reproduce that chart with the red wine data set using its target column instead.
#
# ![](data:image/png;base64,...)

# %%
# YOUR CHANGES HERE

# plot, added in the figsize statement so they wouldn't be so close to each other 
q5 = red_wine.groupby("target").mean(numeric_only=True).plot(subplots=True, figsize=(10,12))
# add title to all
plt.suptitle("Wine Quality Subplots")
# add labels to em all
for ax in q5:
    ax.set_xlabel("Target");
    ax.set_ylabel("Mean Value")

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 6 (manually graded)
#
# Plot the correlation matrix of the red wine data set as a heat map.

# %% [markdown]
# Hint: this visualization was performed for the Palmer penguins data set in the video "Quick Visualizations pf the Palmer Penguins.

# %%
# YOUR CHANGES HERE

# plot
plt.matshow(red_wine.corr(numeric_only=True))
# labels
plt.title("Wine Quality Heat Map")
# add color bar
plt.colorbar(label="Correlation Coefficient")

# add labels to columns
cols = red_wine.corr(numeric_only=True).columns
plt.xticks(ticks=np.arange(len(cols)), labels=cols, rotation=90)
plt.yticks(ticks=np.arange(len(cols)), labels=cols)
# Out:
# ([<matplotlib.axis.YTick at 0x79ec21b5a360>,
#   <matplotlib.axis.YTick at 0x79ec21fc5580>,
#   <matplotlib.axis.YTick at 0x79ec2aa85e50>,
#   <matplotlib.axis.YTick at 0x79ec225f93a0>,
#   <matplotlib.axis.YTick at 0x79ec225a86e0>,
#   <matplotlib.axis.YTick at 0x79ec225ab530>,
#   <matplotlib.axis.YTick at 0x79ec225aabd0>,
#   <matplotlib.axis.YTick at 0x79ec225a8590>,
#   <matplotlib.axis.YTick at 0x79ec225f84a0>,
#   <matplotlib.axis.YTick at 0x79ec225a9820>,
#   <matplotlib.axis.YTick at 0x79ec29fd1760>,
#   <matplotlib.axis.YTick at 0x79ec220f0c80>],
#  [Text(0, 0, 'fixed acidity'),
#   Text(0, 1, 'volatile acidity'),
#   Text(0, 2, 'citric acid'),
#   Text(0, 3, 'residual sugar'),
#   Text(0, 4, 'chlorides'),
#   Text(0, 5, 'free sulfur dioxide'),
#   Text(0, 6, 'total sulfur dioxide'),
#   Text(0, 7, 'density'),
#   Text(0, 8, 'pH'),
#   Text(0, 9, 'sulphates'),
#   Text(0, 10, 'alcohol'),
#   Text(0, 11, 'target')])

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 7 (manually graded)
#
# Plot a box plot of the alcohol column grouping the data by the target column.

# %%
# YOUR CHANGES HERE

# plot
red_wine.plot.box(column="alcohol", by="target")
# labels
plt.title("Wine Quality by Alcohol")
plt.xlabel("Target Wine Quality")
plt.ylabel("Alcohol")
# Out:
# Text(0, 0.5, 'Alcohol')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 8 (manually graded)
#
# Hexagonal bin plots are an alternative to scatter plots that helps visualize density instead of individual points.
# Make a hexagonal bin plot of the residual sugar and alcohol in the red wine data set.

# %% [markdown]
# Hint: pandas has built-in support for hexagonal bin plots.
# The default grid size that pandas uses is fairly small, so you may want to adjust it to your taste.

# %%
# YOUR CHANGES HERE

# plot
q8_hexplot = red_wine.plot.hexbin(x="residual sugar", y="alcohol", gridsize=25)
# title
plt.title("Sugar and Alcohol Hex. Bin Plots")
# add a color bar label
q8_hexplot.figure.axes[-1].set_ylabel("Count (Density)")
# Out:
# Text(0, 0.5, 'Count (Density)')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 9 (manually graded)
#
# Make a scatter plot of the red wine data set's target column and each of the other columns in that data set.
# Make one chart for each of the other columns.

# %%
# YOUR CHANGES HERE

# reference code Abalone.plot.scatter("Length", "Diameter", alpha=0.05)

# fixed acidity
plt.figure()
red_wine.plot.scatter("target", "fixed acidity", alpha=0.05)
plt.title("Fixed Acidity")
plt.ylabel("fixed acidity")
plt.xlabel("target")

# volatile acidity
plt.figure()
red_wine.plot.scatter("target", "volatile acidity", alpha=0.05)
plt.title("Volatile Acidity")
plt.ylabel("volatile acidity")
plt.xlabel("target")

# citric acid
plt.figure()
red_wine.plot.scatter("target", "citric acid", alpha=0.05)
plt.title("Citric Acid")
plt.ylabel("citric acid")
plt.xlabel("target")

# residual sugar
plt.figure()
red_wine.plot.scatter("target", "residual sugar", alpha=0.05)
plt.title("Residual Sugar")
plt.ylabel("residual sugar")
plt.xlabel("target")

# chlorides
plt.figure()
red_wine.plot.scatter("target", "chlorides", alpha=0.05)
plt.title("Chlorides")
plt.ylabel("chlorides")
plt.xlabel("target")

# free sulfur dioxide
plt.figure()
red_wine.plot.scatter("target", "free sulfur dioxide", alpha=0.05)
plt.title("Free Sulfur Dioxide")
plt.ylabel("free sulfur dioxide")
plt.xlabel("target")

# total sulfur dioxide
plt.figure()
red_wine.plot.scatter("target", "total sulfur dioxide", alpha=0.05)
plt.title("Total Sulfur Dioxide")
plt.ylabel("total sulfur dioxide")
plt.xlabel("target")

# density
plt.figure()
red_wine.plot.scatter("target", "density", alpha=0.05)
plt.title("Density")
plt.ylabel("density")
plt.xlabel("target")

# pH
plt.figure()
red_wine.plot.scatter("target", "pH", alpha=0.05)
plt.title("pH")
plt.ylabel("pH")
plt.xlabel("target")

# sulphates
plt.figure()
red_wine.plot.scatter("target", "sulphates", alpha=0.05)
plt.title("Sulphates")
plt.ylabel("sulphates")
plt.xlabel("target")

# alcohol
plt.figure()
red_wine.plot.scatter("target", "alcohol", alpha=0.05)
plt.title("Alcohol")
plt.ylabel("alcohol")
plt.xlabel("target")
# Out:
# /tmp/ipykernel_1939/2090724097.py:76: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure()
# Text(0.5, 0, 'target')

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %% [markdown]
# ### Problem 10 (manually graded)
#
# Pick a pair of input columns in the red wine data set that looks interesting when colored by the target column.
# By interesting, the target values (colors) should be visibly different for some combination of your chosen input columns.

# %% [markdown]
# Hint: use scatter matrix to investigate possible columns, but don't leave it in your notebook as it will make the autograder very slow.

# %%
# YOUR CHANGES HERE

# start with a scatter matrix
# pd.plotting.scatter_matrix(red_wine, c=red_wine["target"])

# find our unique values
q10_choices = red_wine['target'].unique()
# print (q10_choices)

# now color code those choices
q10_colors = dict(zip(q10_choices, plt.rcParams["axes.prop_cycle"].by_key()["color"][:len(q10_choices)]))
# print (q10_colors)
# {np.int64(5): '#1f77b4', np.int64(6): '#ff7f0e', np.int64(7): '#2ca02c', np.int64(4): '#d62728', np.int64(8): '#9467bd', np.int64(3): '#8c564b'}

# map the colors
red_wine["color"] = red_wine['target'].map(q10_colors)


# columns of interest - alcohol and citric acid
plt.scatter(red_wine["alcohol"], red_wine["citric acid"], c=red_wine["color"], alpha= 0.5)

# add titles / labels
plt.title("Relationship between Alcohol and Citric Acid on Wine Quality")
plt.xlabel("Alcohol")
plt.ylabel("Citric Acid")

# make a custom legend
for q10_value in sorted(q10_colors.keys()):
    q10_color = q10_colors[q10_value]
    plt.scatter([], [], color=q10_color, label=f"Quality {q10_value}")

plt.legend(title="Wine Quality")

# %% [markdown]
# <div style="page-break-after: always;"></div>

# %%
# attempt 1 - realized in class this isnt what they're looking for
# # start with a scatter matrix
# # pd.plotting.scatter_matrix(red_wine, c=red_wine["target"])

# # columns of interest - alcohol and citric acid
# red_wine.plot.scatter("alcohol", "citric acid", c="target", cmap="viridis")
# plt.title("Relationship between Alcohol and Citric Acid on Wine Quality")

# %%
# attempt 2 - messy!
# # YOUR CHANGES HERE

# # start with a scatter matrix
# # pd.plotting.scatter_matrix(red_wine, c=red_wine["target"])

# # find our unique values
# q10_choices = red_wine['target'].unique()
# # print (q10_choices)

# # now color code those choices
# q10_colors = dict(zip(q10_choices, plt.rcParams["axes.prop_cycle"].by_key()["color"][:len(q10_choices)]))
# # print (q10_colors)
# # {np.int64(5): '#1f77b4', np.int64(6): '#ff7f0e', np.int64(7): '#2ca02c', np.int64(4): '#d62728', np.int64(8): '#9467bd', np.int64(3): '#8c564b'}

# # map the colors
# red_wine["color"] = red_wine['target'].map(q10_colors)


# # columns of interest - alcohol and citric acid
# # red_wine.plot.scatter("alcohol", "citric acid", c=red_wine["color"])
# # plt.scatter(subset["alcohol"], subset["citric acid"], color=color, label=f"Quality {value}", alpha=0.7)
# plt.scatter(red_wine["alcohol"], red_wine["citric acid"], c=red_wine["color"], alpha= 0.5)

# # add a titles
# plt.title("Relationship between Alcohol and Citric Acid on Wine Quality")
# # plt.xlabel("alcohol")
# # plt.ylabel("citric acid")

# # make a custom legend
# for q10_value in sorted(q10_colors.keys()):
#     q10_color = q10_colors[q10_value]
#     plt.scatter([], [], color=q10_color, label=f"Quality {q10_value}")

#     plt.legend(title="Wine Quality")

# %% [markdown]
# ### Problem 11 (automatically graded)
#
# Set `p11` to the value of $(3 + \mathrm{sin}(2))^5$.

# %%
# YOUR CHANGES HERE

p11 = (3+(math.sin(2)))**5

# %%
p11
# Out:
# 913.0479132098069

# %% [markdown]
# ### Problem 12 (automatically graded)
#
# Write a function `p12` that takes in a sequence of strings and returns a list of the strings starting with the prefix "input_".
# The list should be in the same order as the input sequence.

# %%
# YOUR CHANGES HERE

def p12(column_names):
    # list comprehension 
    q12 = [col for col in column_names if col.startswith("input_")]
    return q12

# %%
# should return ["input_0", "input_1"]
p12(["input_0", "input_1", "target"])
# Out:
# ['input_0', 'input_1']

# %% [markdown]
# ### Problem 13 (automatically graded)
#
# Sort the list `p13` so that the tuples are sorted in order of their second entry (the strings).

# %%
# DO NOT CHANGE

p13 = [(0, "zebra"), (1, "yellow"), (2, "xylophone"), (3, "dog"), (4, "elephant"), (5, "apple")]

# %%
# YOUR CHANGES HERE

p13 = sorted(p13, key=lambda item: item[1])
print (p13)
# Out:
# [(5, 'apple'), (3, 'dog'), (4, 'elephant'), (2, 'xylophone'), (1, 'yellow'), (0, 'zebra')]

# %% [markdown]
# ### Problem 14 (automatically graded)
#
# Set `p14` to be a string with the value of the mathematical constant $\pi$ showing exactly 8 digits after the decimal point (include zeros as necessary).
# For your convenience, `q14` has a copy of $\pi$.

# %%
# DO NOT CHANGE

q14 = math.pi
q14
# Out:
# 3.141592653589793

# %%
# YOUR CHANGES HERE

p14 = (f"{q14:.8f}")
print (p14)
# print (type(p14))
# Out:
# 3.14159265

# %%
# attempt 1 - not a string!
# p14 = round(q14, 8)
# print (p14)

# %% [markdown]
# ### Problem 15 (automatically graded)
#
# Plot the data in variables `x15` and `y15` as a line chart and save it to the file `p15.png`.

# %%
# DO NOT CHANGE

x15 = np.linspace(-10, 10)
y15 = x15 ** 2 - 2 * x15 + 1

# %%
# YOUR CHANGES HERE

# plot the points
plt.plot(x15, y15)

# add labels
plt.title("Problem 15 Plot")
plt.xlabel("x")
plt.ylabel("y")

# save the file 
plt.savefig("p15.png")

# %% [markdown]
# ### Problem 16 (automatically graded)
#
# Set `p16` to be a $253 \times 512$ NumPy array filled entirely with the number 42.

# %%
# YOUR CHANGES HERE

p16 = np.full((253,512),42)
# print (p16)

# %% [markdown]
# ### Problem 17 (automatically graded)
#
# Set `p17` to be a view of array `q17` that has size $1000000 \times 3$ where each row is a copy of `q17`.

# %% [markdown]
# Hint: use broadcasting.

# %%
# DO NOT CHANGE

q17 = np.array([1, 3, 5])
q17
# Out:
# array([1, 3, 5])

# %%
# YOUR CHANGES HERE

p17 = np.broadcast_to(q17, (1000000, 3))

# %%
p17
# Out:
# array([[1, 3, 5],
#        [1, 3, 5],
#        [1, 3, 5],
#        ...,
#        [1, 3, 5],
#        [1, 3, 5],
#        [1, 3, 5]], shape=(1000000, 3))

# %% [markdown]
# ### Problem 18 (automatically graded)
#
# Set `p18` to be a Pandas series with the mean of each column of the red wine data set.
# The index of `p18` should be the column names of the red wine data set.

# %%
# YOUR CHANGES HERE

p18 = red_wine.mean(numeric_only=True)

print (p18)
# print(type(p18))
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# target                   5.636023
# dtype: float64

# %%
# attempt 1 ValueError: Data must be 1-dimensional, got ndarray of shape (1599, 12) instead
# # save the column names
# p18_cols = red_wine.columns
# # print (p18_cols)

# # find the means & make it into a Series
# p18 = pd.Series(red_wine).mean()

# # set the index
# p18 = p18.set_index(p18_cols)

# %%
p18
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# target                   5.636023
# dtype: float64

# %% [markdown]
# ### Problem 19 (automatically graded)
#
# The data frame in `q19` contains the first names of actors and their hometowns.
# Set `p19` to be a data frame of pairs of actors with the same hometown.
# `p19` should have two columns, `name_1` and `name_2` and the value in `name_1` should before the value in `name_2` to avoid matching an actor with themselves and repeating a pair with both orders.

# %%
# DO NOT CHANGE

q19 = pd.DataFrame({"name": ["Mel", "John", "Tom", "Benjamin", "Michael", "Emily", "Tom"],
                    "hometown": ["Peekskill", "Newton", "Concord", "Newton", "Newton", "London", "London"]})
q19
# Out:
#        name   hometown
# 0       Mel  Peekskill
# 1      John     Newton
# 2       Tom    Concord
# 3  Benjamin     Newton
# 4   Michael     Newton
# 5     Emily     London
# 6       Tom     London

# %%
# YOUR CHANGES HERE

# group by
p19_groupby = q19.groupby("hometown")

# testing the group by
# for hometown, group in p19_groupby:
#     print(hometown)
#     print(group)

# empty list to store them in
p19_pairs = []

# get the groups in a format i can work with
for hometown, group in p19_groupby:
    p19_towngroup = group["name"].tolist()
    # print(hometown, p19_towngroup)
    # find the pairs
    for a in range(len(p19_towngroup)):
        for b in range(a+1, len(p19_towngroup)):
            if a != b:
                name_1, name_2 = sorted([p19_towngroup[a], p19_towngroup[b]])
                p19_pairs.append((name_1, name_2))
                # print (p19_pairs)

# turn it into a DF
p19 = pd.DataFrame(p19_pairs, columns=['name_1', 'name_2'])
print (p19)
# Out:
#      name_1   name_2
# 0     Emily      Tom
# 1  Benjamin     John
# 2      John  Michael
# 3  Benjamin  Michael

# %%
# attempt 1 - empty data frame
# # YOUR CHANGES HERE

# # group by
# p19_groupby = q19.groupby("hometown")

# # testing the group by
# # for hometown, group in p19_groupby:
# #     print(hometown)
# #     print(group)

# # get the groups in a format i can work with
# for hometown, group in p19_groupby:
#     p19_towngroup = group["name"].tolist()
#     # print(hometown, p19_towngroup)

# # find the pairs
#     # empty list to store them in
# p19_pairs = []
# for a in range(len(p19_towngroup)):
#     for b in range(a+1, len(p19_towngroup)):
#         p19_pairs.append((p19_towngroup[a], p19_towngroup[b]))
#         # print (p19_pairs)

# # turn it into a DF
# p19 = pd.DataFrame(p19_pairs, columns=['name_1', 'name_2'])
# print (p19)

# %%
# attempt 2 - failed autograder:
# Test Failed: Items in the first set but not the second:
# ('John', 'Benjamin')
# Items in the second set but not the first:
# ('Benjamin', 'John')

# # group by
# p19_groupby = q19.groupby("hometown")

# # testing the group by
# # for hometown, group in p19_groupby:
# #     print(hometown)
# #     print(group)

# # empty list to store them in
# p19_pairs = []

# # get the groups in a format i can work with
# for hometown, group in p19_groupby:
#     p19_towngroup = group["name"].tolist()
#     # print(hometown, p19_towngroup)
#     # find the pairs
#     for a in range(len(p19_towngroup)):
#         for b in range(a+1, len(p19_towngroup)):
#             p19_pairs.append((p19_towngroup[a], p19_towngroup[b]))
#             # print (p19_pairs)

# # turn it into a DF
# p19 = pd.DataFrame(p19_pairs, columns=['name_1', 'name_2'])
# print (p19)

# %% [markdown]
# ### Problem 20 (automatically graded)
#
# Set `p20` to be a data frame with data from the red wine data set indexed on its target where each column has the mean values for that column and target value.
# `p20` should have a column for each of the input columns of the red wine data set.

# %%
# YOUR CHANGES HERE

# calculate the means
p20_means = red_wine.groupby("target").mean(numeric_only=True)
# print (p20_means)

# make it a DF
p20 = pd.DataFrame(p20_means)
print (p20)
# Out:
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
# target
# 3            8.360000          0.884500     0.171000        2.635000
# 4            7.779245          0.693962     0.174151        2.694340
# 5            8.167254          0.577041     0.243686        2.528855
# 6            8.347179          0.497484     0.273824        2.477194
# 7            8.872362          0.403920     0.375176        2.720603
# 8            8.566667          0.423333     0.391111        2.577778
#
#         chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# target
# 3        0.122500            11.000000             24.900000  0.997464
# 4        0.090679            12.264151             36.245283  0.996542
# 5        0.092736            16.983847             56.513950  0.997104
# 6        0.084956            15.711599             40.869906  0.996615
# 7        0.076588            14.045226             35.020101  0.996104
# 8        0.068444            13.277778             33.444444  0.995212
#
#               pH  sulphates    alcohol
# target
# 3       3.398000   0.570000   9.955000
# 4       3.381509   0.596415  10.265094
# 5       3.304949   0.620969   9.899706
# 6       3.318072   0.675329  10.629519
# 7       3.290754   0.741256  11.465913
# 8       3.267222   0.767778  12.094444

# %%
# attempt 1 ValueError: Length mismatch: Expected 6 rows, received array of length 12
# # save the column names
# p20_cols = red_wine.columns
# # print (p20_cols)

# # calculate the means
# p20_means = red_wine.groupby("target").mean()
# # print (p20_means)

# # make it a DF
# p20 = pd.DataFrame(p20_means)
# # print (p20)

# # set the index
# p20 = p20.set_index(p20_cols)
# # print (p20, type(p20))
